# %% [markdown]
# <a href="https://colab.research.google.com/github/MaddalenaDona/Possible-counter-intuitive-impact-of-local-vaccine-mandates-for-vaccine-preventable-infectious-disea/blob/main/Figure1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.core.function_base import linspace
import numpy as np
import matplotlib.pyplot as plt
import math

v=np.linspace(0,1,5000)

#The following function fun finds the dominant eigenvalue of matrix A'
def fun(v):
  out=((lambdaG)*(1-v) + np.sqrt((lambdaG)**2*(1-v)**2+4*(nc-1)*(1-v)**2*(lambdaG)/(1-p)))/2
  return out

nc=25 # number of students in a class
R0=15 #basic reproduction number
lambdaG=(R0**2)/(R0+nc-1) #global infection rate
R_v=[]
p=0
u=[]
for i in range(10):
  u.append(np.linspace(p,1,1000))
  R_v.append(fun(u[i]))
  p=p+0.1

R=[]
p=0
for i in range(10):
  R.append(fun(v))
  p=p+0.1

A=['tab:blue','tab:orange','tab:green','tab:red','tab:purple','tab:brown','tab:pink','tab:gray','tab:olive','tab:cyan']

Q=plt.figure(figsize=(10,8))
axes= Q.add_axes([0.1,0.1,0.8,0.8])
for i in range(len(R_v)):
  plt.plot(u[i],R_v[i], color=A[i])
  #adjust colors
axes.set_ylim([0,4])
axes.set_xlim([0.7,1])
plt.xlabel('Fraction of vaccinated people v', fontsize=18)
plt.ylabel('$R_{0,e}$', fontsize=18)
plt.legend(['$\pi$=0','$\pi$=0.1','$\pi$=0.2','$\pi$=0.3','$\pi$=0.4','$\pi$=0.5','$\pi$=0.6','$\pi$=0.7','$\pi$=0.8','$\pi$=0.9'], fontsize=18)
